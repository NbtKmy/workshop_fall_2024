# %%
# !pip install -q mistralai
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 229.7/229.7 kB 6.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.4/76.4 kB 3.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.0/78.0 kB 3.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 1.2 MB/s eta 0:00:00

# %%
import os
from google.colab import userdata
from mistralai import Mistral

# %%
model = "open-mixtral-8x7b"

client = Mistral(api_key=userdata.get("MISTRALAI_KEY"))

chat_response = client.chat.complete(
    model= model,
    messages = [
        {
            "role": "user",
            "content": "What is the best French cheese?",
        },
    ]
)
print(chat_response.choices[0].message.content)
# Out:
# It's impossible to declare a single "best" French cheese, as cheeses vary greatly in terms of taste, texture, and production methods, and people have different preferences. However, France is renowned for its vast array of high-quality cheeses. Here are a few noteworthy ones:
#
# 1. Comté: A firm cheese from the Franche-Comté region, made from unpasteurized cow's milk. It has a complex, nutty flavor and can be aged for several years.
# 2. Brie de Meaux: A soft, creamy cheese from the Brie region. It has a mild, slightly tangy flavor and a velvety, white rind.
# 3. Roquefort: A blue-veined sheep's milk cheese from the Roquefort-sur-Soulzon region. It's known for its tangy, salty flavor and crumbly texture.
# 4. Camembert de Normandie: A soft, bloomy-rind cheese from Normandy, made from raw cow's milk. It has a rich, earthy flavor and a soft, gooey interior.
# 5. Reblochon: A soft, washed-rind cheese from the Savoie region, made from raw cow's milk. It's characterized by its pungent aroma, creamy texture, and mild, slightly sweet flavor.
#
# These are just a few examples of the many delicious French cheeses. Ultimately, the "best" cheese is a matter of personal taste.

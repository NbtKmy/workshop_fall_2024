# %%
# !pip install -q langchain huggingface_hub transformers langchain_community
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.4/50.4 kB 1.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 51.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 65.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 404.4/404.4 kB 25.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 295.8/295.8 kB 20.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.4/76.4 kB 5.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.0/78.0 kB 6.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.3/49.3 kB 3.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 141.9/141.9 kB 11.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 4.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 4.1 MB/s eta 0:00:00

# %%
from langchain_community.llms.huggingface_pipeline import HuggingFacePipeline
from transformers import pipeline
from google.colab import userdata
import os

os.environ["HUGGING_FACE_HUB_TOKEN"] = userdata.get("HUGGING_FACE")

model_id = "google/gemma-2-2b"

pipe = pipeline(
    "text-generation",
    model=model_id,
    torch_dtype="auto",
    device_map="auto",
    max_new_tokens=100,
    temperature=0.7,
    repetition_penalty=1.2
)

llm = HuggingFacePipeline(pipeline=pipe)
# Out:
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]

# %%
prompt = "Was ist die Hauptstadt von der Schweiz?"
response = llm(prompt)
print(response)
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:567: UserWarning: `do_sample` is set to `False`. However, `temperature` is set to `0.7` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`.
#   warnings.warn(
# Was ist die Hauptstadt von der Schweiz?
#
# Die Antwort auf diese Frage lautet Bern. Die Stadt liegt im Berner Oberland und hat eine Bevölkerung von 130'000 Einwohnern, was sie zu einer relativ kleinen Schweizer Metropole macht. Sie wurde bereits vor über tausend Jahren gegründet und war bis zum Ende des Zweiten Weltkriegs das politische Zentrum der Eidgenossenschaft (Schweiz). Heute sind es in erster Linie Touristen, welche sich für einen Besuch anlocken lassen: Das historische Altstadtviertel mit seinen zahlreichen Sehenswürdigkeiten wie dem Bundes
